# %%
# loading libraries
import pandas as pd
import networkx as nx
import os
from tqdm import tqdm
import statistics
import seaborn as sns
import matplotlib.pyplot as plt
import ray

# %%
def createGeneConverter():
    test = []
    geneId_geneName = {}
    with open('Homo_sapiens.GRCh37.74.gtf', 'r') as file:
        for line in file:
            line = line.strip()
            data = line.split('\t')[-1]
            test.append(data)
            if 'gene_name' in data:
                attributes = data.split(';')
                geneId = attributes[0].split(' ')[1].strip('"')
                for attr in attributes:
                    if 'gene_name' in attr:
                        geneName = attr.split(' ')[2].strip('"')
                        if geneId not in geneId_geneName:
                            geneId_geneName[geneId] = geneName
    geneName_geneId = {v: k for k, v in geneId_geneName.items()}
    return geneName_geneId, geneId_geneName

def createRegulatory(regulatory_filepath):
    geneName_geneId, geneId_geneName = createGeneConverter()
    # loading, cleaning, and permutating regulatory dataset
    print(f'Loading: {regulatory_filepath}')
    regulatory = pd.read_csv(regulatory_filepath, index_col=0)
    
    exceptions = []
    for name in regulatory.index:
        try:
            regulatory = regulatory.rename(index={name: geneName_geneId[name]})
        except:
            exceptions.append(name)
    
    print(f'Row exception count: {len(exceptions)}')
    
    for exc in exceptions:
        regulatory = regulatory.drop(exc)

    # if columns are ENSG IDs, uncomment this part
    exceptions = []
    for ID in regulatory.columns.tolist():
        if ID not in geneId_geneName:
            exceptions.append(ID)

    # if columns are gene names, uncomment this part
    # exceptions = []
    # for name in regulatory.columns.tolist():
    #     try:
    #         regulatory = regulatory.rename(columns={name: geneName_geneId[name]})
    #     except:
    #         exceptions.append(name)

    
    print(f'Column exception count: {len(exceptions)}')

    for exc in exceptions:
        regulatory = regulatory.drop(exc)

    
    def inverse(x):
        return 1/x
    
    def absolute(x):
        return abs(x)
    
    regulatory = regulatory.map(inverse)
    regulatory = regulatory.map(absolute)

    return regulatory

def createEndpoints(filepath):
    geneName_geneId, geneId_geneName = createGeneConverter()
    # loading and cleaning dataset
    endpoints = pd.read_csv(filepath, sep='\t', index_col=0)
    
    exceptions = []
    for name in endpoints.index:
        try:
            endpoints = endpoints.rename(index={name: geneName_geneId[name.upper()]})
        except:
            exceptions.append(name)
    
    print(f'Endpoints exception count: {len(exceptions)}')
    
    for exc in exceptions:
        endpoints = endpoints.drop(exc)

    return list(endpoints.index)

def createRandomEndpoints(regulatory, num, seed):
    rand = regulatory.sample(n=num, random_state=seed)
    return list(rand.index)

def createGraph(regulatory, endpoints):
    # creating network
    regMatrix = regulatory.to_numpy().tolist()
    
    G = nx.Graph()
    nodes = list(set(list(regulatory.index) + regulatory.columns.tolist() + endpoints))
    G.add_nodes_from(nodes)
    edgeCount = 0
    for rowName, row in zip(regulatory.index, regMatrix):
        for columnName, cell in zip(regulatory.columns.tolist(), row):
            # if cell < 10:
            G.add_edge(rowName, columnName, weight=cell)
            edgeCount += 1
    
    print(f'EdgeCount: {edgeCount}')

    return G

@ray.remote
def processData(G, params):
    origin, endpoints = params
    count = {}
    for i, endpoint in enumerate(endpoints):
        print(i)
        try:
            path = nx.shortest_path(G, origin, endpoint, weight="weight")
            path.pop(0)
            path.pop()
            for node in path:
                if node not in count:
                    count[node] = 1
                else:
                    count[node] += 1
        except:
            pass
        
    return count

def connectionEnrichment(origins, endpoints):
    datasets = os.listdir('data')
    datasets = [dataset for dataset in datasets if dataset != '.DS_Store']
    count = {}

    for dataset in datasets:
        regulatory = createRegulatory(f'data/{dataset}')
        G = createGraph(regulatory, endpoints)
        dataId = ray.put(G)
        resultIds = [processData.remote(dataId, (origin, endpoints)) for origin in origins]
        output = ray.get(resultIds)
        
        for dic in output:
            for key, val in dic.items():
                if key not in count:
                    count[key] = 1
                else:
                    count[key] += 1
    return count
    
def sortDic(dic):
    return dict(reversed(sorted(dic.items(), key=lambda item: item[1])))

def printResultsWithStats(dic):
    print(f'Size: {len(dic)}')
    print(f'Average: {statistics.mean(dic.values())}')
    print(f'Median: {statistics.median(dic.values())}')
    print(dic)

# %%
ray.init(num_cpus=8, ignore_reinit_error=True)
# Out:
# 2025-03-27 14:24:48,231	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# RayContext(dashboard_url='127.0.0.1:8265', python_version='3.12.2', ray_version='2.44.0', ray_commit='{{RAY_COMMIT_SHA}}')
# (processData pid=49690) 0
# (processData pid=49692) 0
# (processData pid=49692) 1
# (processData pid=49694) 0
# (processData pid=49696) 0
# (processData pid=49695) 0
# (processData pid=49695) 1
# (processData pid=49695) 2
# (processData pid=49695) 3
# (processData pid=49695) 4
# (processData pid=49695) 5
# (processData pid=49695) 6
# (processData pid=49695) 7
# (processData pid=49695) 8
# (processData pid=49695) 9
# (processData pid=49695) 10
# (processData pid=49695) 11
# (processData pid=49695) 12
# (processData pid=49695) 13
# (processData pid=49695) 14
# (processData pid=49695) 15
# (processData pid=49695) 16
# (processData pid=49695) 17
# (processData pid=49695) 18
# (processData pid=49695) 19
# (processData pid=49695) 20
# (processData pid=49695) 21
# (processData pid=49695) 22
# (processData pid=49695) 23
# (processData pid=49695) 24
# (processData pid=49695) 25
# (processData pid=49695) 26
# (processData pid=49695) 27
# (processData pid=49695) 28
# (processData pid=49695) 29
# (processData pid=49695) 30
# (processData pid=49695) 31
# (processData pid=49695) 32
# (processData pid=49695) 33
# (processData pid=49695) 34
# (processData pid=49695) 35
# (processData pid=49695) 36
# (processData pid=49695) 37
# (processData pid=49695) 38
# (processData pid=49695) 39
# (processData pid=49695) 40
# (processData pid=49695) 41
# (processData pid=49695) 42
# (processData pid=49695) 43
# (processData pid=49695) 44
# (processData pid=49695) 45
# (processData pid=49695) 46
# (processData pid=49695) 47
# (processData pid=49695) 48
# (processData pid=49695) 49
# (processData pid=49695) 50
# (processData pid=49695) 51
# (processData pid=49695) 52
# (processData pid=49695) 53
# (processData pid=49695) 54
# (processData pid=49695) 55
# (processData pid=49695) 56
# (processData pid=49695) 57
# (processData pid=49695) 58
# (processData pid=49695) 59
# (processData pid=49695) 60
# (processData pid=49695) 61
# (processData pid=49695) 62
# (processData pid=49695) 63
# (processData pid=49695) 64
# (processData pid=49695) 65
# (processData pid=49695) 66
# (processData pid=49695) 67
# (processData pid=49695) 68
# (processData pid=49695) 69
# (processData pid=49695) 70
# (processData pid=49695) 71
# (processData pid=49695) 72
# (processData pid=49695) 73
# (processData pid=49695) 74
# (processData pid=49695) 75
# (processData pid=49695) 76
# (processData pid=49695) 77
# (processData pid=49695) 78
# (processData pid=49695) 79
# (processData pid=49695) 80
# (processData pid=49695) 81
# (processData pid=49695) 82
# (processData pid=49695) 83
# (processData pid=49695) 84
# (processData pid=49695) 85
# (processData pid=49695) 86
# (processData pid=49695) 87
# (processData pid=49695) 88
# (processData pid=49695) 89
# (processData pid=49695) 90
# (processData pid=49695) 91
# (processData pid=49695) 92
# (processData pid=49695) 93
# (processData pid=49695) 94
# (processData pid=49695) 95
# (processData pid=49695) 96
# (processData pid=49695) 97
# (processData pid=49695) 98
# (processData pid=49695) 99
# (processData pid=49695) 100
# (processData pid=49695) 101
# (processData pid=49695) 102
# (processData pid=49695) 103
# (processData pid=49695) 104
# (processData pid=49695) 105
# (processData pid=49695) 106
# (processData pid=49695) 107
# (processData pid=49695) 108
# (processData pid=49695) 109
# (processData pid=49695) 110
# (processData pid=49695) 111
# (processData pid=49695) 112
# (processData pid=49695) 113
# (processData pid=49695) 114
# (processData pid=49695) 115
# (processData pid=49695) 116
# (processData pid=49695) 117
# (processData pid=49695) 118
# (processData pid=49695) 119
# (processData pid=49695) 120
# (processData pid=49695) 121
# (processData pid=49695) 122
# (processData pid=49695) 123
# (processData pid=49695) 124
# (processData pid=49695) 125
# (processData pid=49695) 126
# (processData pid=49695) 127
# (processData pid=49695) 128
# (processData pid=49695) 129
# (processData pid=49695) 130
# (processData pid=49695) 131
# (processData pid=49695) 132
# (processData pid=49695) 133
# (processData pid=49695) 134
# (processData pid=49695) 135
# (processData pid=49695) 136
# (processData pid=49695) 137
# (processData pid=49695) 138
# (processData pid=49695) 139
# (processData pid=49695) 140
# (processData pid=49695) 141
# (processData pid=49695) 142
# (processData pid=49695) 143
# (processData pid=49695) 144
# (processData pid=49695) 145
# (processData pid=49695) 146
# (processData pid=49695) 147
# (processData pid=49695) 148
# (processData pid=49695) 149
# (processData pid=49695) 150
# (processData pid=49695) 151
# (processData pid=49695) 152
# (processData pid=49695) 153
# (processData pid=49695) 154
# (processData pid=49695) 155
# (processData pid=49695) 156
# (processData pid=49695) 157
# (processData pid=49695) 158
# (processData pid=49695) 159
# (processData pid=49695) 160
# (processData pid=49695) 161
# (processData pid=49695) 162
# (processData pid=49695) 163
# (processData pid=49695) 164
# (processData pid=49695) 165
# (processData pid=49695) 166
# (processData pid=49695) 167
# (processData pid=49695) 168
# (processData pid=49695) 169
# (processData pid=49695) 170
# (processData pid=49695) 171
# (processData pid=49695) 172
# (processData pid=49695) 173
# (processData pid=49695) 174
# (processData pid=49695) 175
# (processData pid=49695) 176
# (processData pid=49695) 177
# (processData pid=49695) 178
# (processData pid=49695) 179
# (processData pid=49695) 180
# (processData pid=49695) 181
# (processData pid=49695) 182
# (processData pid=49695) 183
# (processData pid=49695) 184
# (processData pid=49695) 185
# (processData pid=49695) 186
# (processData pid=49695) 187
# (processData pid=49695) 188
# (processData pid=49695) 189
# (processData pid=49695) 190
# (processData pid=49695) 191
# (processData pid=49695) 192
# (processData pid=49695) 193
# (processData pid=49695) 194
# (processData pid=49695) 195
# (processData pid=49695) 196
# (processData pid=49695) 197
# (processData pid=49695) 198
# (processData pid=49695) 199
# (processData pid=49695) 200
# (processData pid=49695) 201
# (processData pid=49695) 202
# (processData pid=49695) 203
# (processData pid=49695) 204
# (processData pid=49695) 205
# (processData pid=49695) 206
# (processData pid=49695) 207
# (processData pid=49695) 208
# (processData pid=49695) 209
# (processData pid=49695) 210
# (processData pid=49695) 211
# (processData pid=49695) 212
# (processData pid=49695) 213
# (processData pid=49695) 214
# (processData pid=49695) 215
# (processData pid=49695) 216
# (processData pid=49695) 217
# (processData pid=49695) 218
# (processData pid=49695) 219
# (processData pid=49695) 220
# (processData pid=49695) 221
# (processData pid=49695) 222
# (processData pid=49695) 223
# (processData pid=49695) 224
# (processData pid=49695) 225
# (processData pid=49695) 226
# (processData pid=49695) 227
# (processData pid=49695) 228
# (processData pid=49695) 229
# (processData pid=49695) 230
# (processData pid=49695) 231
# (processData pid=49695) 232
# (processData pid=49695) 233
# (processData pid=49695) 234
# (processData pid=49695) 235
# (processData pid=49695) 236
# (processData pid=49695) 237
# (processData pid=49695) 238
# (processData pid=49695) 239
# (processData pid=49695) 240
# (processData pid=49695) 241
# (processData pid=49695) 242
# (processData pid=49695) 243
# (processData pid=49695) 244
# (processData pid=49695) 245
# (processData pid=49695) 246
# (processData pid=49695) 247
# (processData pid=49695) 248
# (processData pid=49695) 249
# (processData pid=49695) 250
# (processData pid=49695) 251
# (processData pid=49695) 252
# (processData pid=49695) 253
# (processData pid=49695) 254
# (processData pid=49695) 255
# (processData pid=49695) 256
# (processData pid=49695) 257
# (processData pid=49695) 258
# (processData pid=49695) 259
# (processData pid=49695) 260
# (processData pid=49695) 261
# (processData pid=49695) 262
# (processData pid=49695) 263
# (processData pid=49695) 264
# (processData pid=49695) 265
# (processData pid=49695) 266
# (processData pid=49695) 267
# (processData pid=49695) 268
# (processData pid=49695) 269
# (processData pid=49695) 270
# (processData pid=49695) 271
# (processData pid=49695) 272
# (processData pid=49695) 273
# (processData pid=49695) 274
# (processData pid=49695) 275
# (processData pid=49695) 276
# (processData pid=49695) 277
# (processData pid=49695) 278
# (processData pid=49695) 279
# (processData pid=49695) 280
# (processData pid=49695) 281
# (processData pid=49695) 282
# (processData pid=49695) 283
# (processData pid=49695) 284
# (processData pid=49695) 285
# (processData pid=49695) 286
# (processData pid=49695) 287
# (processData pid=49695) 288
# (processData pid=49695) 289
# (processData pid=49695) 290
# (processData pid=49695) 291
# (processData pid=49695) 292
# (processData pid=49695) 293
# (processData pid=49695) 294
# (processData pid=49695) 295
# (processData pid=49695) 296
# (processData pid=49695) 297
# (processData pid=49695) 298
# (processData pid=49695) 299
# (processData pid=49695) 300
# (processData pid=49695) 301
# (processData pid=49695) 302
# (processData pid=49695) 303
# (processData pid=49695) 304
# (processData pid=49695) 305
# (processData pid=49695) 306
# (processData pid=49695) 307
# (processData pid=49695) 308
# (processData pid=49695) 309
# (processData pid=49689) 0
# (processData pid=49693) 0
# (processData pid=49691) 0
# (processData pid=49692) 2
# (processData pid=49692) 3
# (processData pid=49694) 1
# (processData pid=49694) 2
# (processData pid=49694) 3
# (processData pid=49690) 1
# (processData pid=49692) 4
# (processData pid=49691) 1
# (processData pid=49689) 1
# (processData pid=49696) 1
# (processData pid=49694) 4
# (processData pid=49690) 2
# (processData pid=49690) 3
# (processData pid=49690) 4
# (processData pid=49693) 1
# (processData pid=49690) 5
# (processData pid=49696) 2
# (processData pid=49696) 3
# (processData pid=49691) 2
# (processData pid=49691) 3
# (processData pid=49692) 5
# (processData pid=49689) 2
# (processData pid=49689) 3
# (processData pid=49690) 6
# (processData pid=49696) 4
# (processData pid=49689) 4
# (processData pid=49689) 5
# (processData pid=49696) 5
# (processData pid=49696) 6
# (processData pid=49692) 6
# (processData pid=49694) 5
# (processData pid=49693) 2
# (processData pid=49693) 3
# (processData pid=49695) 0
# (processData pid=49691) 4
# (processData pid=49690) 7
# (processData pid=49696) 7
# (processData pid=49692) 7
# (processData pid=49689) 6
# (processData pid=49696) 8
# (processData pid=49693) 4
# (processData pid=49694) 6
# (processData pid=49691) 5
# (processData pid=49695) 1
# (processData pid=49692) 8
# (processData pid=49691) 6
# (processData pid=49696) 9
# (processData pid=49691) 7
# (processData pid=49691) 8
# (processData pid=49694) 7
# (processData pid=49690) 8
# (processData pid=49693) 5
# (processData pid=49689) 7
# (processData pid=49692) 9
# (processData pid=49691) 9
# (processData pid=49695) 2
# (processData pid=49695) 3
# (processData pid=49696) 10
# (processData pid=49693) 6
# (processData pid=49693) 7
# (processData pid=49690) 9
# (processData pid=49694) 8
# (processData pid=49693) 8
# (processData pid=49696) 11
# (processData pid=49692) 10
# (processData pid=49696) 12
# (processData pid=49689) 8
# (processData pid=49691) 10
# (processData pid=49694) 9
# (processData pid=49696) 13
# (processData pid=49694) 10
# (processData pid=49691) 11
# (processData pid=49693) 9
# (processData pid=49690) 10
# (processData pid=49695) 4
# (processData pid=49689) 9
# (processData pid=49691) 12
# (processData pid=49690) 11
# (processData pid=49689) 10
# (processData pid=49696) 14
# (processData pid=49692) 11
# (processData pid=49695) 5
# (processData pid=49690) 12
# (processData pid=49694) 11
# (processData pid=49689) 11
# (processData pid=49692) 12
# (processData pid=49695) 6
# (processData pid=49693) 10
# (processData pid=49690) 13
# (processData pid=49691) 13
# (processData pid=49696) 15
# (processData pid=49689) 12
# (processData pid=49693) 11
# (processData pid=49692) 13
# (processData pid=49695) 7
# (processData pid=49694) 12
# (processData pid=49693) 12
# (processData pid=49691) 14
# (processData pid=49689) 13
# (processData pid=49690) 14
# (processData pid=49696) 16
# (processData pid=49696) 17
# (processData pid=49692) 14
# (processData pid=49694) 13
# (processData pid=49691) 15
# (processData pid=49693) 13
# (processData pid=49695) 8
# (processData pid=49695) 9
# (processData pid=49689) 14
# (processData pid=49692) 15
# (processData pid=49696) 18
# (processData pid=49690) 15
# (processData pid=49691) 16
# (processData pid=49691) 17
# (processData pid=49692) 16
# (processData pid=49692) 17
# (processData pid=49694) 14
# (processData pid=49694) 15
# (processData pid=49695) 10
# (processData pid=49691) 18
# (processData pid=49696) 19
# (processData pid=49694) 16
# (processData pid=49694) 17
# (processData pid=49689) 15
# (processData pid=49690) 16
# (processData pid=49690) 17
# (processData pid=49693) 14
# (processData pid=49696) 20
# (processData pid=49692) 18
# (processData pid=49696) 21
# (processData pid=49689) 16
# (processData pid=49689) 17
# (processData pid=49691) 19
# (processData pid=49696) 22
# (processData pid=49690) 18
# (processData pid=49692) 19
# (processData pid=49693) 15
# (processData pid=49695) 11
# (processData pid=49689) 18
# (processData pid=49694) 18
# (processData pid=49693) 16
# (processData pid=49693) 17

# %%
# multi-dataset aging gene enrichment
globalAgingGenes = createEndpoints('global_aging_genes.tsv')
agingCount = connectionEnrichment(globalAgingGenes, globalAgingGenes)
# Out:
# Endpoints exception count: 15
# Loading: data/Testis.csv
# Row exception count: 0
# Column exception count: 0
# EdgeCount: 19476492

# %%
## printing results
printResultsWithStats(sortDic(agingCount))

# %%
# control experiment 1
datasets = os.listdir('data')
datasets = [dataset for dataset in datasets if dataset != '.DS_Store']
regulatory = createRegulatory(f'data/{datasets[0]}')
globalAgingGenes = createEndpoints('global_aging_genes.tsv')
randomGenes = createRandomEndpoints(regulatory, len(globalAgingGenes), 42)
controlCount1 = connectionEnrichment(randomGenes, randomGenes)

# %%
# printing results
printResultsWithStats(sortDic(controlCount1))

# %%
# control experiment 2
datasets = os.listdir('data')
datasets = [dataset for dataset in datasets if dataset != '.DS_Store']
regulatory = createRegulatory(f'data/{datasets[0]}')
globalAgingGenes = createEndpoints('global_aging_genes.tsv')
randomGenes = createRandomEndpoints(regulatory, len(globalAgingGenes), 43)
controlCount2 = connectionEnrichment(randomGenes, randomGenes)

# %%
# printing results
printResultsWithStats(sortDic(controlCount2))

# %%
# control experiment 3
datasets = os.listdir('data')
datasets = [dataset for dataset in datasets if dataset != '.DS_Store']
regulatory = createRegulatory(f'data/{datasets[0]}')
globalAgingGenes = createEndpoints('global_aging_genes.tsv')
randomGenes = createRandomEndpoints(regulatory, len(globalAgingGenes), 44)
controlCount3 = connectionEnrichment(randomGenes, randomGenes)

# %%
# printing results
printResultsWithStats(sortDic(controlCount3))

# %%
# creating graph
agingVal = list(agingCount.values())
controlVal1 = list(controlCount1.values())
controlVal2 = list(controlCount2.values())
controlVal3 = list(controlCount3.values())
agingName = ['aging' for i in range(len(agingVal))]
controlName1 = ['control1' for i in range(len(controlVal1))]
controlName2 = ['control2' for i in range(len(controlVal2))]
controlName3 = ['control3' for i in range(len(controlVal3))]

counts = agingVal + controlVal1 + controlVal2 + controlVal3
names = agingName + controlName1 + controlName2 + controlName3

df = pd.DataFrame({'counts': counts, 'names': names})

sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    df,
    x="counts", hue="names",
    multiple="dodge",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    bins = 16,
)

plt.yscale('log')
plt.xlabel("Number of overlaps")

# %%
for name1, dataset1 in zip(['aging', 'control1', 'control2', 'control3'], [agingCount, controlCount1, controlCount2, controlCount3]):
    print(f'Origin: {name1}')
    for name2, dataset2 in zip(['aging', 'control1', 'control2', 'control3'], [agingCount, controlCount1, controlCount2, controlCount3]):
        print(f'Endpoint: {name2}')
        intersection = set(dataset1).intersection(set(dataset2))
        sideTotal2 = sum([dataset2[i] for i in intersection])
        print(f'{len(intersection)} // {sideTotal2} // {int(sideTotal2 / len(intersection))}')

# %%
genageDF = pd.read_csv("genage_human.csv")
genageList = list(genageDF['symbol'])
genageENSGList = [geneName_geneId[name] for name in genageList]

# %%
# experiment
filteredAgingCount = {k:v for k,v in agingCount.items() if k in genageENSGList}

# %%
printResultsWithStats(sortDic(filteredAgingCount))

# %%
# control 1
filteredControlCount1 = {k:v for k,v in controlCount1.items() if k in genageENSGList}

# %%
printResultsWithStats(sortDic(filteredControlCount1))

# %%
# control 1
filteredControlCount2 = {k:v for k,v in controlCount2.items() if k in genageENSGList}

# %%
printResultsWithStats(sortDic(filteredControlCount2))

# %%
# control 1
filteredControlCount3 = {k:v for k,v in controlCount3.items() if k in genageENSGList}

# %%
printResultsWithStats(sortDic(filteredControlCount3))

# %%
# creating graph
agingVal = list(filteredAgingCount.values())
controlVal1 = list(filteredControlCount1.values())
controlVal2 = list(filteredControlCount2.values())
controlVal3 = list(filteredControlCount3.values())
agingName = ['aging' for i in range(len(agingVal))]
controlName1 = ['control1' for i in range(len(controlVal1))]
controlName2 = ['control2' for i in range(len(controlVal2))]
controlName3 = ['control3' for i in range(len(controlVal3))]

counts = agingVal + controlVal1 + controlVal2 + controlVal3
names = agingName + controlName1 + controlName2 + controlName3

df = pd.DataFrame({'counts': counts, 'names': names})

sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    df,
    x="counts", hue="names",
    multiple="dodge",
    palette="light:m_r",
    edgecolor=".3",
    linewidth=.5,
    bins = 16,
)

plt.yscale('log')
plt.xlabel("Number of overlaps between central genes and GenAge")
